# %%
import pandas as pd
import numpy as np
import typing
from nltk.tokenize import sent_tokenize

# %%
aviationData = pd.read_csv("narrativesAviationCsv.csv", encoding='mac-roman').fillna('')
aviationData
# Out:
#                 ev_id  Aircraft_Key  \
# 0      20001204X00000             1
# 1      20001204X00001             1
# 2      20001204X00002             1
# 3      20001204X00003             1
# 4      20001204X00004             1
# ...               ...           ...
# 63907  20101006X81741             1
# 63908  20120502X05030             1
# 63909  20121004X53806             1
# 63910  20170710X10920             1
# 63911  20170710X52551             1
#
#                                                narr_accf  \
# 0      The certificated commercial pilot reported tha...
# 1      After landing, the number four engine thrust r...
# 2      The certificated airline transport pilot, with...
# 3      The certificated private pilot departed the ac...
# 4      The certificated commercial pilot reported tha...
# ...                                                  ...
# 63907
# 63908
# 63909  While maneuvering at 3,000 feet over the Atlan...
# 63910  While on a cross-country flight over mountaino...
# 63911  The Safety Board's full report is available at...
#
#                                               narr_cause Unnamed: 4  \
# 0      Loss of engine power due to fracture of the en...
# 1      The improper overhaul of the thrust reverser p...
# 2      The failure of the driver of a vehicle to main...
# 3      The pilot's attempted flight into adverse weat...
# 4      The pilot's continued flight into adverse weat...
# ...                                                  ...        ...
# 63907
# 63908
# 63909  Extensive salt buildup in the inlets of all fo...
# 63910  Failure by the pilot-in-command, for unknown r...
# 63911  a fatigue fracture of the aft cabin pressure b...
#
#         lchg_date lchg_userid
# 0      12/12/2000         dbo
# 1      12/12/2000         dbo
# 2       4/27/2001         dbo
# 3       4/27/2001         dbo
# 4      12/12/2000         dbo
# ...           ...         ...
# 63907  11/10/2011
# 63908    5/2/2012
# 63909   5/23/2013
# 63910   9/19/2017
# 63911   9/19/2017
#
# [63912 rows x 7 columns]

# %%
trueReports = aviationData.narr_accf.astype('string').apply(sent_tokenize).values

# %%
eleven_sentence_reports = [report for report in trueReports if len(report) == 11][:100]

# %%
import random

random.seed(487)
num_permutations_per_report = 20

permutations = []
for report in eleven_sentence_reports:
    for _ in range(num_permutations_per_report):
        shuffled = report.copy()
        random.shuffle(shuffled)
        if report != shuffled:
            permutations.append(shuffled)
            
print(permutations[0])
print(eleven_sentence_reports[0])
# Out:
# ['The airplane cruising endurance based on 75% power and 90 gallons of fuel on board is 5.4 hours.', 'A Federal Aviation Administration inspector who examined the airplane noted only residual fuel was found in the selector valve and no leaks were found in the fuel system.', 'During descent, the engine began running rough and the pilot decided the tanks had been exhausted.', 'However, the usable fuel capacity on this airplane when the fuel tanks are filled to the bottom of the filler necks is approximately 80 gallons.', 'The pilot performed a forced landing causing substantial damage.', 'During this time, the engine began running smoothly whereupon the pilot continued to his initial destination.', 'Shortly after departing, the engine began running rough upon which the pilot began a deviation to another airport.', 'The preflight inspection of the fuel tanks by the pilot revealed the tanks were filled to the bottom of the filler neck, which the pilot believed was appropriately full.', 'After starting the engine, fuel began leaking from the fuel sump drain hose.', 'The pilot operated the spring loaded valve handle inside the airplane which apparently stopped the leak.', 'The actual flight time of this aircraft was 5.55 hours.']
# ['The preflight inspection of the fuel tanks by the pilot revealed the tanks were filled to the bottom of the filler neck, which the pilot believed was appropriately full.', 'Shortly after departing, the engine began running rough upon which the pilot began a deviation to another airport.', 'During this time, the engine began running smoothly whereupon the pilot continued to his initial destination.', 'During descent, the engine began running rough and the pilot decided the tanks had been exhausted.', 'A Federal Aviation Administration inspector who examined the airplane noted only residual fuel was found in the selector valve and no leaks were found in the fuel system.', 'The pilot operated the spring loaded valve handle inside the airplane which apparently stopped the leak.', 'However, the usable fuel capacity on this airplane when the fuel tanks are filled to the bottom of the filler necks is approximately 80 gallons.', 'The airplane cruising endurance based on 75% power and 90 gallons of fuel on board is 5.4 hours.', 'The pilot performed a forced landing causing substantial damage.', 'The actual flight time of this aircraft was 5.55 hours.', 'After starting the engine, fuel began leaking from the fuel sump drain hose.']

# %%
# should be true
len(eleven_sentence_reports) == len(permutations) / 20
# Out:
# True

# %%
joined_reports = [' '.join(report) for report in eleven_sentence_reports]
joined_perms = [' '.join(perm) for perm in permutations]
print(joined_reports[0])
print(joined_perms[0])

# %%
d = {
    'paragraph': joined_reports + joined_perms,
    'is_coherent': [1] * 100 + [0] * 2000
}
pars_with_label = pd.DataFrame(d)
pars_with_label
# Out:
#                                               paragraph  is_coherent
# 0     The preflight inspection of the fuel tanks by ...            1
# 1     However, drop size, drop distribution, and aer...            1
# 2     Subsequently, the controller re-identified the...            1
# 3     The pilot's last radio transmission was a rout...            1
# 4     The pilot reported the right engine experience...            1
# ...                                                 ...          ...
# 2095  EACH FUEL TANK HOLDS 25 GALLONS OF FUEL, OF WH...            0
# 2096  THE RIGHT WING FUEL TANK WAS EMPTY. THE FUEL S...            0
# 2097  RESIDUAL FUEL WAS FOUND IN THE CARBURETOR BOWL...            0
# 2098  FUEL AND AIRPLANE RECORDS REVEALED THE AIRPLAN...            0
# 2099  DURING AN INTENTIONAL MANEUVER TO AVOID A HOME...            0
#
# [2100 rows x 2 columns]

# %%
pars_with_label.to_csv('aviationPerms.csv', index=False)

# %%
reconstructed = pd.read_csv('aviationPerms.csv')
reconstructed
# Out:
#                                               paragraph  is_coherent
# 0     The preflight inspection of the fuel tanks by ...            1
# 1     However, drop size, drop distribution, and aer...            1
# 2     Subsequently, the controller re-identified the...            1
# 3     The pilot's last radio transmission was a rout...            1
# 4     The pilot reported the right engine experience...            1
# ...                                                 ...          ...
# 2095  EACH FUEL TANK HOLDS 25 GALLONS OF FUEL, OF WH...            0
# 2096  THE RIGHT WING FUEL TANK WAS EMPTY. THE FUEL S...            0
# 2097  RESIDUAL FUEL WAS FOUND IN THE CARBURETOR BOWL...            0
# 2098  FUEL AND AIRPLANE RECORDS REVEALED THE AIRPLAN...            0
# 2099  DURING AN INTENTIONAL MANEUVER TO AVOID A HOME...            0
#
# [2100 rows x 2 columns]
